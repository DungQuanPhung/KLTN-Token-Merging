# %%
# !git clone https://github.com/hotuyen21pt/KLTN-Token-Merging.git
# Out:
# Cloning into 'KLTN-Token-Merging'...
# remote: Enumerating objects: 2621, done.
# remote: Counting objects: 100% (2379/2379), done.
# remote: Compressing objects: 100% (1600/1600), done.
# remote: Total 2621 (delta 767), reused 2353 (delta 754), pack-reused 242 (from 1)
# Receiving objects: 100% (2621/2621), 11.71 MiB | 19.12 MiB/s, done.
# Resolving deltas: 100% (881/881), done.

# %%
# !ls
# Out:
# KLTN-Token-Merging  sample_data  thesis_apc_baseline

# %%
# !pip install -r /content/thesis_apc_baseline/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 574.2/574.2 kB 31.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.3/153.3 kB 18.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 16.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 98.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.2/54.2 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.3/175.3 kB 21.2 MB/s eta 0:00:00
# ...
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16162 sha256=a6a4c5a7d1a6a4b125acd6d2b857b9a3f37e1655b11243e83e5d951b772a8657
#   Stored in directory: /root/.cache/pip/wheels/5f/b8/73/0b2c1a76b701a677653dd79ece07cfabd7457989dbfbdcd8d7
# Successfully built seqeval
# ...

# %%
# !ls
# Out:
# KLTN-Token-Merging  sample_data  thesis_apc_baseline

# %%
# %cd thesis_apc_baseline
# !python experiments/run_joint_experiments.py
# Out:
# /content/thesis_apc_baseline
# Device  : cuda
# Model   : bert-base-uncased
# Seed    : 42
# Runs dir: /content/thesis_apc_baseline/runs_joint
#
# Supplement: disabled (USE_SUPPLEMENT=False)
# ...
# config.json: 100% 570/570 [00:00<00:00, 2.38MB/s]
# tokenizer_config.json: 100% 48.0/48.0 [00:00<00:00, 246kB/s]
# vocab.txt: 100% 232k/232k [00:00<00:00, 1.36MB/s]
# tokenizer.json: 100% 466k/466k [00:00<00:00, 1.36MB/s]
# Sentiment classes  (3): ['positive', 'negative', 'neutral']
# Aspect-cat classes (6): ['AMENITY', 'BRANDING', 'EXPERIENCE', 'FACILITY', 'LOYALTY', 'SERVICE']
#
# Building datasets … (clause_split=True)
# [ApcFileDataset] clause_split=True: 1147/2448 samples shortened to aspect clause
# [ApcFileDataset] clause_split=True: 139/304 samples shortened to aspect clause
# [ApcFileDataset] clause_split=True: 148/312 samples shortened to aspect clause
#   Train: 2448 samples (2448 main + 0 supplement)
#   Dev: 304 | Test: 312
#   Train sentiment distribution:
# ...
