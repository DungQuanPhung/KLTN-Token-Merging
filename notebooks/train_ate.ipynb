# %%
# !git clone https://github.com/hotuyen21pt/KLTN-Token-Merging.git
# Out:
# Cloning into 'KLTN-Token-Merging'...
# remote: Enumerating objects: 266, done.
# remote: Counting objects: 100% (266/266), done.
# remote: Compressing objects: 100% (195/195), done.
# remote: Total 266 (delta 134), reused 182 (delta 69), pack-reused 0 (from 0)
# Receiving objects: 100% (266/266), 2.06 MiB | 6.04 MiB/s, done.
# Resolving deltas: 100% (134/134), done.

# %%
# !ls
# Out:
# drive  KLTN-Token-Merging  sample_data	thesis_apc_baseline

# %%
# !pip install -r thesis_apc_baseline/requirements.txt

# %%
# !ls
# Out:
# drive  KLTN-Token-Merging  sample_data	thesis_apc_baseline

# %%
# !python thesis_apc_baseline/src/train.py
# Out:
# Data dir   : /content/thesis_apc_baseline/dataset
# Output dir : /content/thesis_apc_baseline/checkpoints/gas_t5_ate
# Model      : t5-base
# Device     : cuda
# ...
# [ATE] train: 2322 sentences  (train.apc)
# [ATE] dev: 303 sentences  (dev.apc)
# [ATE] test: 309 sentences  (test.apc)
# [ATE] dev: 303 sentences  (dev.apc)
# [ATE] test: 309 sentences  (test.apc)
# Loading weights: 100% 257/257 [00:00<00:00, 493.63it/s]
# /content/thesis_apc_baseline/src/trainer.py:67: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = amp.GradScaler(enabled=self.use_amp)
# /content/thesis_apc_baseline/src/trainer.py:80: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(enabled=self.use_amp):
# ...

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import torch

MODEL_PATH = "/content/thesis_apc_baseline/checkpoints/gas_t5_ate/best"

# Load model và tokenizer
tokenizer = AutoTokenizer.from_pretrained(MODEL_PATH)
model = AutoModelForSeq2SeqLM.from_pretrained(MODEL_PATH)

# Inference
sentence = "the food was delicious but the staff was rude"

inputs = tokenizer(
    sentence,
    return_tensors="pt",
    truncation=True,
    max_length=128
)

with torch.no_grad():
    outputs = model.generate(
        **inputs,
        max_length=64,
        num_beams=4
    )

prediction = tokenizer.decode(
    outputs[0],
    skip_special_tokens=True
)

print("Sentence:")
print(sentence)
print("\nPrediction:")
print(prediction)
# Out:
# Loading weights:   0%|          | 0/257 [00:00<?, ?it/s]
# Sentence:
# the food was delicious but the staff was rude
#
# Prediction:
# (food)
