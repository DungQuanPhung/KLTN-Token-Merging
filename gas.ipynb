# %%
# !git clone https://github.com/hotuyen21pt/KLTN-Token-Merging.git
# Out:
# Cloning into 'KLTN-Token-Merging'...
# remote: Enumerating objects: 2605, done.
# remote: Counting objects: 100% (2363/2363), done.
# remote: Compressing objects: 100% (1590/1590), done.
# remote: Total 2605 (delta 757), reused 2341 (delta 749), pack-reused 242 (from 1)
# Receiving objects: 100% (2605/2605), 11.69 MiB | 13.21 MiB/s, done.
# Resolving deltas: 100% (871/871), done.

# %%
# !ls
# Out:
# KLTN-Token-Merging  sample_data

# %%
# !pip install -r /content/thesis_apc_baseline/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 3.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 574.2/574.2 kB 22.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.3/153.3 kB 16.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 24.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 99.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.2/54.2 kB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.3/175.3 kB 18.3 MB/s eta 0:00:00
# ...
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16162 sha256=0a2bdcca04d8b2227682c990ad08bec56127fe9952889a050dc9c2fcca9b748a
#   Stored in directory: /root/.cache/pip/wheels/5f/b8/73/0b2c1a76b701a677653dd79ece07cfabd7457989dbfbdcd8d7
# Successfully built seqeval
# ...

# %%
# !ls
# Out:
# sample_data  thesis_apc_baseline

# %%
# %cd thesis_apc_baseline
# !python gas/train_gas.py --data-dir dataset --output-dir checkpoints/gas_t5
# Out:
# /content/thesis_apc_baseline
# Data dir      : dataset
# Output dir    : checkpoints/gas_t5
# Model         : t5-base
# Device        : cuda
# Target format : (aspect_term, CATEGORY, sentiment)
# ...
# spiece.model: 100% 792k/792k [00:00<00:00, 3.53MB/s]
# tokenizer.json: 100% 1.39M/1.39M [00:00<00:00, 5.93MB/s]
# [GAS] train.apc: 2322 sentences
# [GAS] dev.apc: 303 sentences
# [GAS] test.apc: 309 sentences
# config.json: 100% 1.21k/1.21k [00:00<00:00, 2.98MB/s]
# model.safetensors: 100% 892M/892M [00:16<00:00, 53.8MB/s]
# Loading weights: 100% 257/257 [00:00<00:00, 4805.93it/s]
# generation_config.json: 100% 147/147 [00:00<00:00, 750kB/s]
# /content/thesis_apc_baseline/gas/trainer.py:90: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler  = amp.GradScaler(enabled=self.use_amp)
# ...

# %%
# %cd thesis_apc_baseline
# !python gas/evaluate_joint.py --gas-checkpoint checkpoints/gas_t5/best --data-dir dataset
# Out:
# [Errno 2] No such file or directory: 'thesis_apc_baseline'
# /content/thesis_apc_baseline
# Device: cuda
# Loading GAS model from: checkpoints/gas_t5/best
# Loading weights: 100% 257/257 [00:00<00:00, 4947.23it/s]
# Loading test data from: dataset
# [GAS] test.apc: 309 sentences
#   309 sentences
#
# Running evaluation on test split ...
#
# ...
# 3-LABEL ABSA EVALUATION  (single-stage GAS T5)
#   Split      : test
#   Checkpoint : checkpoints/gas_t5/best
#   Sentences  : 309
# ...
# ------------------------------------------------------------------------
# Aspect Term     P=0.7961  R=0.7885  F1=0.7923  (TP=246 FP=63 FN=66)
# Category        P=0.7411  R=0.7340  F1=0.7375  (TP=229 FP=80 FN=83)
# Sentiment       P=0.7573  R=0.7500  F1=0.7536  (TP=234 FP=75 FN=78)
# Joint (all 3)   P=0.7087  R=0.7019  F1=0.7053  (TP=219 FP=90 FN=93)
# ------------------------------------------------------------------------
# Definitions:
#   Aspect Term  -- exact match on aspect string
# ...

# %%
# %cd thesis_apc_baseline
# !python gas/infer.py --checkpoint checkpoints/gas_t5/best --text "The food was great"
# Out:
# [Errno 2] No such file or directory: 'thesis_apc_baseline'
# /content/thesis_apc_baseline
# Device     : cuda
# Checkpoint : checkpoints/gas_t5/best
# Loading weights: 100% 257/257 [00:00<00:00, 4869.39it/s]
#
# Sentence : The food was great
#   [1] aspect='food'                category=AMENITY           sentiment=positive
